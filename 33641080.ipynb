# %% [markdown]
# Here, we are trying to follow the readme to infer the package and use its abilities.<br>
# Before everything let's try to infer:<br>

# %%
import torch
from model import Model
model = Model(device = "cuda", dtype = torch.float16)
# Out:
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <module>:2                                                                                    │
# │                                                                                                  │
# │   1 import torch                                                                                 │
# │ ❱ 2 from model import Model                                                                      │
# │   3 model = Model(device = "cuda", dtype = torch.float16)                                        │
# │   4                                                                                              │
# │                                                                                                  │
# │ /home/arvin/PycharmProjects/pythonProject/Text2Video-Zero/model.py:9 in <module>                 │
# ...

# %% [markdown]
# Here is a Text to Video prompt:

# %%
prompt = "A horse galloping on a street"
params = {"t0": 44, "t1": 47 , "motion_field_strength_x" : 12, "motion_field_strength_y" : 12, "video_length": 30}

out_path, fps = f"./text2video_{prompt.replace(' ','_')}.mp4", 15
fps, out_path
# Out:
# (4, './text2video_A_horse_galloping_on_a_street.mp4')

# %%
model.process_text2video(prompt, fps = fps, path = out_path, **params)
# Out:
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <module>:1                                                                                    │
# │                                                                                                  │
# │ ❱ 1 model.process_text2video(prompt, fps = fps, path = out_path, **params)                       │
# │   2                                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# NameError: name 'model' is not defined
